# %%
import numpy as np
import pandas as pd
import os
import scipy.io
from scipy.signal import butter, filtfilt, iirnotch, cheby2
from einops import rearrange
import matplotlib.pyplot as plt
import seaborn as sns
import pywt
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim

# %%
import sys

sys.path.append("../../motor-imagery-classification-2024/")

from loaders import EEGDataset,load_data
from models.unet.eeg_unets import Unet,UnetConfig
# Out:
# c:\Users\rahar\anaconda3\envs\neuro\lib\site-packages\torchaudio\backend\utils.py:74: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")

# %%
FS = 250
sns.set_style("darkgrid")

# %%
dataset = {}
for i in range(1,10):
	mat_train,mat_test = load_data("../data/2b_iv",i)
	dataset[f"subject_{i}"] = {"train":mat_train,"test":mat_test}

# %%
import torch.nn.functional as F
from einops import reduce

class FakeClassifier(nn.Module):
    def __init__(self, input_channels):
        super(FakeClassifier, self).__init__()
        self.fc = nn.Linear(input_channels, 2) 

    def forward(self, x):
        x = reduce(x,"b c ... -> b c","mean")
        x = self.fc(x)
        return x

# %%
class DeepClassifier:
    def __init__(self, 
                 mat_dataset,
                 train_split,
                 test_split,
                 batch_size=32, 
                 t_baseline=0, 
                 t_epoch=9, 
                 fs=250,
                 start=3.5,
                 length=2):
        self.fs = fs
        self.t_epoch = t_epoch
        self.t_baseline = t_baseline
        self.batch_size = batch_size
        self.train_loader = self.get_loader(mat_dataset,train_split, batch_size)
        self.val_loader = self.get_loader(mat_dataset,test_split,batch_size)
        self.model = FakeClassifier(input_channels=6)  # Define your input channels here

    def get_loader(self,dataset,splits,batch_size,shuffle=True):
        dset = EEGDataset(dataset,splits,fs=self.fs,t_baseline=self.t_baseline,t_epoch=
                          self.t_epoch)
        return DataLoader(dset,batch_size,shuffle=shuffle)

    def get_val_loader(self, mat_dataset):
        val_dataset = EEGDataset(mat_dataset, train=False, fs=self.fs, t_baseline=self.t_baseline, t_epoch=self.t_epoch)
        return DataLoader(val_dataset, batch_size=self.batch_size, shuffle=False)

    def fit(self, num_epochs=10):
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(self.model.parameters(), lr=0.001)

        self.model.to(device)
        for epoch in range(num_epochs):
            self.model.train()
            running_loss = 0.0
            correct = 0
            total = 0
            for inputs, labels in self.train_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = self.model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                optimizer.zero_grad()
                running_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

            train_accuracy = 100 * correct / total
            val_loss = 0.0
            correct = 0
            total = 0
            self.model.eval()
            with torch.no_grad():
                for inputs, labels in self.val_loader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    outputs = self.model(inputs)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()
                    val_loss += criterion(outputs, labels).item()

            val_accuracy = 100 * correct / total

            print(f'Epoch [{epoch+1}/{num_epochs}], '
                f'Training Loss: {running_loss/len(self.train_loader):.3f}, '
                f'Training Accuracy: {train_accuracy:.2f}%, '
                f'Validation Loss: {val_loss/len(self.val_loader):.3f}, '
                f'Validation Accuracy: {val_accuracy:.2f}%')

        print('Finished Training')
    
    def predict(self,x):
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model.eval()
        inputs = inputs.to(device)
        with torch.no_grad():
            outputs = self.model(inputs)
            _, predicted = torch.max(outputs.data, 1)
        return predicted

# %%
train_split = 6*[["train","test"]] + 3*[["train"]]
test_split = 6*[[]] + 3* [["test"]]

# %%
deep_clf = DeepClassifier(dataset,train_split,test_split)

# %%
deep_clf.fit(25)
# Out:
# Epoch [1/25], Training Loss: 0.867, Training Accuracy: 55.90%, Validation Loss: 0.571, Validation Accuracy: 70.16%
# Epoch [2/25], Training Loss: 0.744, Training Accuracy: 59.34%, Validation Loss: 0.508, Validation Accuracy: 73.55%
# Epoch [3/25], Training Loss: 0.695, Training Accuracy: 61.71%, Validation Loss: 0.504, Validation Accuracy: 75.53%
# Epoch [4/25], Training Loss: 0.670, Training Accuracy: 62.59%, Validation Loss: 0.496, Validation Accuracy: 76.24%
# Epoch [5/25], Training Loss: 0.660, Training Accuracy: 63.16%, Validation Loss: 0.481, Validation Accuracy: 77.93%
# Epoch [6/25], Training Loss: 0.651, Training Accuracy: 63.95%, Validation Loss: 0.462, Validation Accuracy: 78.22%
# Epoch [7/25], Training Loss: 0.646, Training Accuracy: 64.17%, Validation Loss: 0.454, Validation Accuracy: 79.21%
# Epoch [8/25], Training Loss: 0.643, Training Accuracy: 64.54%, Validation Loss: 0.451, Validation Accuracy: 80.06%
# Epoch [9/25], Training Loss: 0.638, Training Accuracy: 64.85%, Validation Loss: 0.447, Validation Accuracy: 80.20%
# Epoch [10/25], Training Loss: 0.637, Training Accuracy: 64.91%, Validation Loss: 0.445, Validation Accuracy: 80.34%
# Epoch [11/25], Training Loss: 0.635, Training Accuracy: 64.87%, Validation Loss: 0.440, Validation Accuracy: 79.92%
# Epoch [12/25], Training Loss: 0.632, Training Accuracy: 64.93%, Validation Loss: 0.442, Validation Accuracy: 80.34%
# Epoch [13/25], Training Loss: 0.632, Training Accuracy: 64.91%, Validation Loss: 0.444, Validation Accuracy: 80.06%
# Epoch [14/25], Training Loss: 0.629, Training Accuracy: 64.74%, Validation Loss: 0.447, Validation Accuracy: 80.76%
# Epoch [15/25], Training Loss: 0.633, Training Accuracy: 65.33%, Validation Loss: 0.447, Validation Accuracy: 80.20%
# Epoch [16/25], Training Loss: 0.628, Training Accuracy: 65.07%, Validation Loss: 0.458, Validation Accuracy: 80.20%
# Epoch [17/25], Training Loss: 0.633, Training Accuracy: 65.44%, Validation Loss: 0.452, Validation Accuracy: 80.34%
# Epoch [18/25], Training Loss: 0.627, Training Accuracy: 65.57%, Validation Loss: 0.443, Validation Accuracy: 80.06%
# Epoch [19/25], Training Loss: 0.631, Training Accuracy: 65.33%, Validation Loss: 0.450, Validation Accuracy: 80.91%
# Epoch [20/25], Training Loss: 0.630, Training Accuracy: 65.46%, Validation Loss: 0.446, Validation Accuracy: 80.06%
# Epoch [21/25], Training Loss: 0.631, Training Accuracy: 65.42%, Validation Loss: 0.451, Validation Accuracy: 80.62%
# Epoch [22/25], Training Loss: 0.626, Training Accuracy: 65.94%, Validation Loss: 0.449, Validation Accuracy: 79.77%
# Epoch [23/25], Training Loss: 0.625, Training Accuracy: 65.37%, Validation Loss: 0.454, Validation Accuracy: 79.77%
# Epoch [24/25], Training Loss: 0.627, Training Accuracy: 65.53%, Validation Loss: 0.446, Validation Accuracy: 79.63%
# Epoch [25/25], Training Loss: 0.626, Training Accuracy: 65.92%, Validation Loss: 0.441, Validation Accuracy: 79.77%
# Finished Training

# %% [markdown]
# - Logistic regression reaches 65% train, 80% test (probably lucky splits)

# %%
batch = next(iter(deep_clf.train_loader))

# %%
batch[0].shape
# Out:
# torch.Size([32, 6, 500])

# %%
widths = np.geomspace(1, 1024, num=64)

# %%
x = rearrange(batch[0],"b c l -> (b c) l")

# %%
y = pywt.cwt(x.numpy(),widths,"cmor1.5-1.0")

# %%
x.shape
# Out:
# torch.Size([192, 500])

# %%
y[0].shape
# Out:
# (64, 192, 500)

# %%
y[1].shape
# Out:
# (64,)

# %%
plt.imshow(np.abs(y[0][:,0,:]))

# %%
decomp = pywt.wavedec(x,"db2",level=6)

# %%
decomp
# Out:
# [array([[-20.709484 , -22.04742  ,   5.7081714, ...,  13.961999 ,
#           -2.7111135,  12.331214 ],
#         [-10.066859 , -13.1399765,  -2.9790602, ...,  16.81889  ,
#          -14.576578 ,   8.744614 ],
#         [ -9.385086 , -11.4127245,  -0.5536952, ...,  11.797388 ,
#           -2.9622617,  18.53124  ],
#         ...,
#         [-10.090132 ,  -3.2127898, -55.49938  , ...,  -7.187612 ,
#           11.838281 , -15.807021 ],
#         [ -5.9294662,  -2.4179304, -63.13102  , ..., -15.164902 ,
#           25.194443 ,  -3.4671803],
#         [-84.011986 , -78.4836   , -89.701675 , ...,  -8.419716 ,
#          -20.906328 ,  38.143772 ]], dtype=float32),
#  array([[ -0.55283165,  -6.8227854 ,   6.83294   , ...,   6.948596  ,
#           -7.1416717 ,   8.532338  ],
#         [  0.36673278, -10.255363  ,   4.628953  , ...,  -0.7422917 ,
#           -3.6778584 ,   7.5811405 ],
#         [  0.14432871,  -7.089609  ,   8.926609  , ...,   3.660676  ,
#           -9.895676  ,  11.955727  ],
#         ...,
#         [ -1.0318239 ,  22.25187   ,  26.876347  , ...,  14.7098255 ,
#           -2.537651  ,  -3.719171  ],
#         [ -2.5637324 ,   4.620813  ,   7.6863637 , ...,  32.795303  ,
#          -43.73796   ,  27.537857  ],
#         [ -1.1706758 ,  16.75799   , -13.226309  , ...,  22.726938  ,
#          -59.7051    ,  57.68097   ]], dtype=float32),
#  array([[ -0.4466704 ,   1.89097   ,  -0.5363502 , ...,  -1.1413716 ,
#           -2.1523829 ,   4.495022  ],
#         [ -0.17777044,  -2.8233373 ,   3.2408166 , ...,   5.214339  ,
#           -1.3009367 ,   3.5269058 ],
#         [  0.24154109,  -0.08024198,   0.28755873, ...,  -1.1029521 ,
#           -3.111841  ,   6.371753  ],
#         ...,
#         [  2.7317407 ,  15.328791  ,  -6.123092  , ...,   7.288432  ,
#            9.959247  ,  -8.848782  ],
#         [  1.5438476 ,  20.733658  , -17.726404  , ...,  14.152558  ,
#           -8.766821  ,  15.897546  ],
#         [  3.2604933 ,  17.924868  ,   9.232155  , ...,  10.88521   ,
#           -8.89117   ,  26.065361  ]], dtype=float32),
#  array([[-0.09298915,  2.4144616 , -1.2340059 , ..., -1.4174181 ,
#           1.9927224 , -0.36052805],
#         [-0.27462476,  0.17456162, -0.7973681 , ..., -5.395942  ,
#           1.2412276 ,  4.206352  ],
#         [ 0.2677819 , -0.5858524 ,  0.5340753 , ..., -5.6907616 ,
#           2.584059  ,  2.8407946 ],
#         ...,
#         [ 3.0310674 , -6.6173387 , -0.19534135, ...,  7.6919    ,
#          -3.9378552 ,  0.91911256],
#         [ 2.9590683 ,  0.3838991 , -7.2750807 , ...,  7.1734476 ,
#           7.573238  , -8.595382  ],
#         [ 5.2309613 , -2.5594401 , -1.1345432 , ...,  2.323906  ,
#          11.785675  , -5.30021   ]], dtype=float32),
#  array([[ -0.22276616,  -0.17051148,   1.1278121 , ...,  -0.6980634 ,
#            1.2628236 ,  -0.19497156],
#         [ -0.11666086,   1.2875987 ,  -3.994377  , ...,   2.679211  ,
#            0.09238791,  -0.33657363],
#         [ -0.10614419,  -1.9832476 ,  -6.776734  , ...,   2.716353  ,
#            1.2006426 ,  -1.5471668 ],
#         ...,
#         [  1.8747237 , -12.268366  ,   0.15662456, ...,  -2.6523917 ,
#           -2.7901125 ,   4.027854  ],
#         [  1.4428675 , -13.2587595 ,   7.308302  , ..., -18.449265  ,
#            5.258359  ,   8.982448  ],
#         [  3.3068714 , -20.935879  ,  13.4699745 , ..., -26.440935  ,
#            6.7040863 ,  16.56456   ]], dtype=float32),
#  array([[-6.0146642e-01, -6.3286698e-01, -1.8163149e+00, ...,
#          -8.1470776e-01,  7.7017146e-01,  2.2098613e-01],
#         [-2.1503419e-03,  7.0386183e-01, -4.5868352e-01, ...,
#          -6.1080700e-01,  8.6458027e-02,  3.1573364e-01],
#         [-2.4930745e-01, -1.7817232e-01, -2.5540867e+00, ...,
#          -7.9780024e-01,  1.0042324e+00, -5.4037237e-01],
#         ...,
#         [ 3.7106061e+00,  8.5454291e-01, -3.9761040e+00, ...,
#           3.7054527e+00, -2.3042829e+00, -1.1848444e-01],
#         [ 1.1490732e+00, -4.9906874e+00, -2.3562984e+00, ...,
#          -3.5466442e+00,  1.2306447e+00,  6.5985813e+00],
#         [ 2.3038588e+00, -1.2529065e+01, -1.8450360e+00, ...,
#          -3.9462113e+00,  5.7857090e-01,  1.0803164e+01]], dtype=float32),
#  array([[-7.6848400e-01,  1.1223609e+00,  5.9685862e-01, ...,
#          -3.0015695e-01,  2.8438702e-01,  1.0735038e-01],
#         [ 4.9065769e-02,  1.7548342e-01, -6.7529909e-02, ...,
#          -6.2582684e-01,  8.3112329e-01, -6.3388753e-01],
#         [-7.9488844e-01, -1.1112227e+00,  8.5293269e-01, ...,
#          -6.8894953e-01, -3.7637353e-03,  5.2738273e-01],
#         ...,
#         [ 6.0218806e+00, -2.6851468e+00, -5.8966875e+00, ...,
#          -1.3721409e+00,  5.0402899e+00, -4.8866792e+00],
#         [ 1.4201444e+00, -2.3031001e+00, -5.6763697e+00, ...,
#          -5.2440748e+00,  2.3677068e+00, -2.0535676e+00],
#         [ 3.1729221e+00, -3.5402031e+00, -7.2533283e+00, ...,
#          -1.7186026e+01,  3.5119373e-01, -1.3254780e+00]], dtype=float32)]

# %%
x_full = []
for i in decomp:
	print(i.shape)
	xi = rearrange(i,"(b c) l -> b c l",b=32)
	xi = reduce(xi,"b c l -> b c","mean")
	x_full.append(xi)
np.concatenate(x_full,-1).shape
# Out:
# (192, 10)
# (192, 10)
# (192, 18)
# (192, 34)
# (192, 65)
# (192, 127)
# (192, 251)
# (32, 42)

# %%
plt.plot(decomp[6][0])

# %%
class WaveletDataset(EEGDataset):

	def __init__(self, dataset, subject_splits, fs=250, t_baseline=0, t_epoch=9, start=3.5, length=0.5):
		self.fs = fs
		self.t_baseline = t_baseline
		self.t_epoch = t_epoch
		self.set_epoch(start,length)
		self.data = self.load_data(dataset,subject_splits)

	def __getitem__(self, idx):
		x,y = self.data[0][idx,:,int(self.input_start*250):int(self.input_end*250)], self.data[1][idx]
		b,c,l = x.shape
		x = rearrange(x,"b c l -> (b c) l")
		decomp = pywt.wavedec(x,"db2",level=6)
		x_full = []
		for i in decomp:
			xi = rearrange(i,"(b c) l -> b c l",b=32)
			xi = reduce(xi,"b c l -> b c","mean")
			x_full.append(xi)
		x = np.concatenate(x_full,-1)
		return x,y

# %%
wdset = WaveletDataset(dataset,train_split)
